# %% [markdown]
# # Analysis in Notebook

# %% [markdown]
# Lipsum

# %% [markdown]
# Initialize pretty plotting with ``matplotlib`` first.
#
# **OPTION 1:** ``%matplotlib notebook`` – Get zoom-able & resize-able figures. NB! Only one figure can be active.
#
# **Option 2:** ``%matplotlib inline`` – Only draws the figure, not interactive / zoom-able.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import code from src
sys.path.insert(0, '../src/')
from setup import fig_path

# %%
# Example
x = np.linspace(0, 2*np.pi, 100)
plt.plot(x, np.sin(x))
plt.show()
